# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Kavyasrimedi/flyrank-week1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose **Refresh / Content Opportunity Scoring** because it focuses on solving a real business problem rather than simply training a machine learning model. Instead of asking whether a page is good or bad, the goal is to identify which content should be reviewed first based on observable search and engagement signals. I find this interesting because it combines data analysis, machine learning, and practical decision-making. Over the next few weeks, I want to learn how evidence-based ranking can help prioritize limited content optimization efforts.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Decision, Action and Cost
#
# **Decision:**
# Determine which content pages should be prioritized for review or refresh.
#
# **Who acts on it?**
# SEO specialists or content teams responsible for maintaining website performance.
#
# **Action:**
# Review the highest-ranked pages first and decide whether to update, expand, optimize, or monitor them.
#
# **Cost of a wrong recommendation:**
# If important pages are missed, valuable search traffic and user engagement may decline. If low-priority pages are incorrectly recommended, the team wastes time and resources that could have been spent on more impactful content.
#
# Machine learning can support this decision by identifying patterns across many search and engagement signals that would be difficult to evaluate manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains thousands of content records with multiple search and engagement metrics. It includes observable signals such as impressions, sessions, CTR, content age, and trend direction, making it suitable for studying content refresh opportunities. The distribution of trend categories and traffic metrics suggests that there are meaningful differences between pages that can be explored through machine learning.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print(df.shape)

print(df["trend_direction"].value_counts())

print(df["content_type"].value_counts().head())

print(df[["impressions_90d","sessions_90d"]].describe())

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## What I Can and Cannot Claim
#
# This project aims to identify patterns that help prioritize content review using observable search and engagement signals. The results should be viewed as decision-support rather than automated decision-making.
#
# The analysis cannot prove that refreshing a page will improve its performance, nor can it predict or explain Google's ranking algorithm. Any recommendations produced by the model should be reviewed by humans before action is taken.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
