# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Kavyasrimedi/flyrank-week1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*<br><br>
# This is primarily a ranking/scoring problem, because the goal is to prioritize which content pages should be reviewed first. A classification model may estimate the probability that a page needs attention, but the final output is a ranked list that helps content teams decide where to focus first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*<br><br>
# For the starter dataset, the proxy target is whether a page is declining (trend_direction == "down"). This helps identify content that may require review. In a larger production setting, a stronger target could be future decline or future recovery measured over a later time window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*<br><br>
# Since the output is a ranked review queue, Precision@K is an appropriate success metric because it measures how many of the highest-priority recommendations are actually useful. Average Precision can also evaluate the overall quality of the ranking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

df.head()

print(df.shape)
df.info()

# %% [markdown]
# Each row represents one content page with search, engagement, and content-related measurements collected over a defined time window.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*<br><br>
# A fixed rule applies the same thresholds to every page and may miss complex interactions between multiple signals. Machine learning can learn patterns across search visibility, engagement, freshness, and content characteristics simultaneously, producing a more informative ranking that adapts better to different situations while still supporting human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✓] Every section above is filled — markdown thinking AND the code that backs it
# - [✓] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✓] No client names, URLs, or private queries anywhere
# - [✓] My claims use careful words: observed, measured, directional, decision-support
# - [✓] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
